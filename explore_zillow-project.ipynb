# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import os
from env import get_db_url
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn.preprocessing
import wrangle_zillow
import scipy.stats as stats
alpha = .05
from sklearn.cluster import KMeans

# %% [markdown]
# ### Acquire

# %%
df = wrangle_zillow.get_zillow_data()

# %%
df.shape
# Out:
# (52441, 68)

# %% [markdown]
# ### Prepare

# %%
# remove rows and columns with more than 30% missing data
df = wrangle_zillow.prepare_zillow_data(df)

# %%
# split data
train, validate, test = wrangle_zillow.split_zillow_data(df)

# %%
train.shape, validate.shape, test.shape
# Out:
# ((21728, 15), (9312, 15), (7761, 15))

# %% [markdown]
# ### Explore
#
# Ask at least 5 questions about the data, keeping in mind that your target variable is logerror. e.g. Is logerror significantly different for properties in LA County vs Orange County vs Ventura County?
#
# Answer those questions through a mix of statistical tests and visualizations.
#
# Bonus:
#
# Compute the mean(logerror) by zipcode and the overall mean(logerror). Write a loop that will run a t-test between the overall mean and the mean for each zip code. We want to identify the zip codes where the error is significantly higher or lower than the expected error.

# %%
df.describe().T
# Out:
#                                 count          mean            std  \
# bathroomcnt                   38801.0  2.057151e+00       0.698323
# bedroomcnt                    38801.0  3.190201e+00       0.776164
# calculatedfinishedsquarefeet  38801.0  1.639604e+03     564.940706
# latitude                      38801.0  3.401946e+07  270521.732089
# longitude                     38801.0 -1.181861e+08  351178.645614
# lotsizesquarefeet             38801.0  6.623087e+03    2026.022353
# regionidcity                  38801.0  3.465884e+04   52651.990158
# regionidzip                   38801.0  9.658180e+04    1594.948267
# yearbuilt                     38801.0  1.961764e+03      20.327878
# taxvaluedollarcnt             38801.0  3.517464e+05  223455.330328
# taxamount                     38801.0  4.358083e+03    2502.958666
# logerror                      38801.0  1.630501e-02       0.159931
#
#                                        min           25%           50%  \
# bathroomcnt                   1.000000e+00  2.000000e+00  2.000000e+00
# bedroomcnt                    2.000000e+00  3.000000e+00  3.000000e+00
# calculatedfinishedsquarefeet  1.520000e+02  1.224000e+03  1.530000e+03
# latitude                      3.334425e+07  3.382814e+07  3.399394e+07
# longitude                    -1.194753e+08 -1.183744e+08 -1.181343e+08
# lotsizesquarefeet             1.350000e+03  5.410000e+03  6.500000e+03
# regionidcity                  3.491000e+03  1.244700e+04  2.481200e+04
# regionidzip                   9.598200e+04  9.621200e+04  9.642600e+04
# yearbuilt                     1.913000e+03  1.950000e+03  1.959000e+03
# taxvaluedollarcnt             3.254000e+03  1.675160e+05  3.241530e+05
# taxamount                     4.900000e+01  2.378000e+03  4.092000e+03
# logerror                     -4.655420e+00 -2.411161e-02  5.636679e-03
#
#                                        75%           max
# bathroomcnt                   2.500000e+00  4.000000e+00
# bedroomcnt                    4.000000e+00  5.000000e+00
# calculatedfinishedsquarefeet  1.960000e+03  3.522000e+03
# latitude                      3.418931e+07  3.471836e+07
# longitude                    -1.179375e+08 -1.175723e+08
# lotsizesquarefeet             7.663000e+03  1.243400e+04
# regionidcity                  4.022700e+04  3.965560e+05
# regionidzip                   9.700100e+04  3.996750e+05
# yearbuilt                     1.975000e+03  2.012000e+03
# taxvaluedollarcnt             4.949560e+05  1.070530e+06
# taxamount                     5.954000e+03  1.151600e+04
# logerror                      3.559088e-02  3.175688e+00

# %%
df.head()
# Out:
#    bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet         fips  \
# 0          3.5           4                          3100       Orange
# 2          2.0           3                          1243       Orange
# 5          1.0           2                           738  Los_Angeles
# 7          3.0           4                          2540  Los_Angeles
# 9          2.5           3                          1371      Ventura
#
#    latitude  longitude  lotsizesquarefeet  regionidcity  regionidzip  \
# 0  33634931 -117869207               4506         53571        96978
# 2  33886168 -117823170               8432         21412        97078
# 5  34149214 -118239357               4214         45457        96325
# 7  34434971 -118464390              10384         54311        96374
# 9  34238229 -119170633               3445         13150        97107
#
#    yearbuilt  taxvaluedollarcnt  taxamount  logerror transactiondate  \
# 0       1998            1023282      11013  0.025595      2017-01-01
# 2       1962             564778       6488  0.005383      2017-01-01
# 5       1922             218552       2366  0.101723      2017-01-01
# 7       1999             430108       6103  0.005963      2017-01-02
# 9       2004             198054       2204  0.008669      2017-01-02
#
#          propertylandusedesc
# 0  Single Family Residential
# 2  Single Family Residential
# 5  Single Family Residential
# 7  Single Family Residential
# 9  Single Family Residential

# %%
#looking at the counts for each column
for column in df.columns:
    print(column)
    print(df[column].value_counts())
    print("-------------------------------")
# Out:
# bathroomcnt
# 2.0    18983
# 1.0     7885
# 3.0     7107
# 2.5     3303
# 1.5      619
# 4.0      595
# 3.5      309
# Name: bathroomcnt, dtype: int64
# -------------------------------
# bedroomcnt
# 3    19339
# 4    10763
# 2     6927
# 5     1772
# Name: bedroomcnt, dtype: int64
# -------------------------------
# calculatedfinishedsquarefeet
# 1120    122
# 1200     99
# 1080     81
# 936      79
# 1400     77
#        ...
# 2913      1
# 3462      1
# 2877      1
# 3009      1
# 512       1
# Name: calculatedfinishedsquarefeet, Length: 2775, dtype: int64
# -------------------------------
# fips
# Los_Angeles    25033
# Orange         10485
# Ventura         3283
# Name: fips, dtype: int64
# -------------------------------
# latitude
# 34229075    4
# 33914773    4
# 34712133    4
# 33873860    4
# 34267979    3
#            ..
# 34043478    1
# 34173982    1
# 33926793    1
# 33728790    1
# 33937685    1
# Name: latitude, Length: 37641, dtype: int64
# -------------------------------
# longitude
# -117847000    5
# -117830000    4
# -117849000    4
# -118398581    4
# -117762000    4
#              ..
# -118167200    1
# -118140773    1
# -118405445    1
# -118157621    1
# -117996709    1
# Name: longitude, Length: 37814, dtype: int64
# -------------------------------
# lotsizesquarefeet
# 6000     821
# 5000     370
# 7200     283
# 7000     260
# 6500     238
#         ...
# 9889       1
# 3593       1
# 4769       1
# 8182       1
# 12004      1
# Name: lotsizesquarefeet, Length: 8401, dtype: int64
# -------------------------------
# regionidcity
# 12447    7786
# 5534     1440
# 46298    1275
# 40227    1205
# 16764     947
#          ...
# 31134       2
# 14906       2
# 36078       1
# 34037       1
# 21395       1
# Name: regionidcity, Length: 167, dtype: int64
# -------------------------------
# regionidzip
# 97319     573
# 97318     545
# 97328     484
# 96193     416
# 97329     403
#          ...
# 97119       1
# 399675      1
# 96039       1
# 96148       1
# 95996       1
# Name: regionidzip, Length: 372, dtype: int64
# -------------------------------
# yearbuilt
# 1955    1678
# 1950    1410
# 1954    1322
# 1953    1287
# 1956    1146
#         ...
# 1933      37
# 1934      36
# 1917      35
# 1916      32
# 2011      28
# Name: yearbuilt, Length: 100, dtype: int64
# -------------------------------
# taxvaluedollarcnt
# 455000    31
# 600000    28
# 500000    24
# 530000    21
# 550000    21
#           ..
# 220451     1
# 496121     1
# 315728     1
# 370475     1
# 49546      1
# Name: taxvaluedollarcnt, Length: 28666, dtype: int64
# -------------------------------
# taxamount
# 3287     19
# 1170     17
# 1096     16
# 869      16
# 1179     16
#          ..
# 8091      1
# 431       1
# 1859      1
# 10398     1
# 1865      1
# Name: taxamount, Length: 9591, dtype: int64
# -------------------------------
# logerror
#  0.000231    5
#  0.000375    4
#  0.000727    4
#  0.018974    4
#  0.003152    4
#             ..
# -0.049930    1
# -0.079077    1
# -0.069269    1
#  0.000445    1
#  0.037129    1
# Name: logerror, Length: 38617, dtype: int64
# -------------------------------
# transactiondate
# 2017-06-30    582
# 2017-04-28    469
# 2017-05-31    429
# 2017-07-28    401
# 2017-08-31    394
#              ...
# 2017-03-25      1
# 2017-07-23      1
# 2017-04-02      1
# 2017-04-08      1
# 2017-09-25      1
# Name: transactiondate, Length: 251, dtype: int64
# -------------------------------
# propertylandusedesc
# Single Family Residential    38801
# Name: propertylandusedesc, dtype: int64
# -------------------------------

# %%
#create all the histograms:
for col in train.columns:
    plt.figure(figsize=(8,4))
    plt.hist(train[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# ### Questions to ask:
#    - Is logerror dependent on county?
#    - Are logerror and tax value related?
#    - Are logerror and lot size related?
#    - Are logerror and squarefeet related?

# %%
plt.figure(figsize=(8,10))
sns.boxplot(x=train.fips.sample(1000), y=train.logerror.sample(1000))
# Out:
# <AxesSubplot:xlabel='fips', ylabel='logerror'>

# %% [markdown]
# **Notes:**
# - LA county's median value is more closely centered around zero, while Ventura and Orange County have higher median logerror.
# - Outliers exist in both LA and Orange counties
#
# Next step:
# - Run statistical tests to determine if there is a difference in each county and the population mean.

# %% [markdown]
# - Null Hypothesis: The mean logerror of LA County is >= than the population mean.
# - Alternative Hypothesis: The mean logerror of LA County is < than the population mean.

# %%
t, p = stats.ttest_1samp(train[train.fips=='Los_Angles'].logerror.mean(), df.logerror.mean())

t, p/2
if p/2 > alpha:
    print("We fail to reject the null hypothesis.")
elif t > 0:
    print("We fail to reject the null hypothesis.")
else:
    print("We reject the null hypothesis.")
# Out:
# We reject the null hypothesis.

# %% [markdown]
# - Null Hypothesis: The mean logerror of Ventura County is <= than the population mean.
# - Alternative Hypothesis: The mean logerror of Ventura County is > than the population mean.

# %%
t, p = stats.ttest_1samp(train[train.fips=='Ventura'].logerror.mean(), df.logerror.mean())
t, p/2
if p/2 > alpha:
    print("We fail to reject the null hypothesis.")
elif t < 0:
    print("We fail to reject the null hypothesis.")
else:
    print("We reject the null hypothesis.")
# Out:
# We reject the null hypothesis.

# %% [markdown]
# - Null Hypothesis: The mean logerror of Orange County is <= than the population mean.
# - Alternative Hypothesis: The mean logerror of Orange County is > than the population mean.

# %%
t, p = stats.ttest_1samp(train[train.fips=='Orange'].logerror.mean(), df.logerror.mean())
t, p/2
if p/2 > alpha:
    print("We fail to reject the null hypothesis.")
elif t < 0:
    print("We fail to reject the null hypothesis.")
else:
    print("We reject the null hypothesis.")
# Out:
# We reject the null hypothesis.

# %% [markdown]
# **Notes: We can conclude, with statistical significance, that the means of the logerror of each county are not equal. LA County's logerror is less than the population, while Orange and Ventura counties' logerror means are greater than the population.**

# %% [markdown]
# ### Logerror and taxvaluedollarcnt

# %%
sns.lmplot(data=train, x='taxvaluedollarcnt',y='logerror',line_kws={'color':'red'})
plt.show()

# %%
train.taxvaluedollarcnt.hist()
# Out:
# <AxesSubplot:>

# %%
# perform correlation testing on square feet to value
alpha=.05
corr, p = stats.spearmanr(train.taxvaluedollarcnt, train.logerror)
p < alpha, corr, p
# Out:
# (False, -0.009619933852524446, 0.15619954117451582)

# %%
corr = pd.DataFrame(train.corr(method='spearman'))
corr
# Out:
#                               bathroomcnt  bedroomcnt  \
# bathroomcnt                      1.000000    0.567875
# bedroomcnt                       0.567875    1.000000
# calculatedfinishedsquarefeet     0.788266    0.613704
# latitude                        -0.021224    0.003718
# longitude                        0.115461    0.070756
# lotsizesquarefeet                0.143177    0.219338
# regionidcity                     0.012897    0.022241
# regionidzip                      0.305933    0.248545
# yearbuilt                        0.605786    0.415431
# taxvaluedollarcnt                0.333486    0.166317
# taxamount                        0.340444    0.176616
# logerror                         0.050648    0.046402
#
#                               calculatedfinishedsquarefeet  latitude  \
# bathroomcnt                                       0.788266 -0.021224
# bedroomcnt                                        0.613704  0.003718
# calculatedfinishedsquarefeet                      1.000000 -0.035241
# latitude                                         -0.035241  1.000000
# longitude                                         0.093949 -0.639187
# lotsizesquarefeet                                 0.270736  0.314863
# regionidcity                                      0.015193 -0.181988
# regionidzip                                       0.263213  0.124467
# yearbuilt                                         0.532038 -0.003511
# taxvaluedollarcnt                                 0.364303 -0.165432
# taxamount                                         0.369713 -0.100355
# logerror                                          0.062921 -0.029925
#
#                               longitude  lotsizesquarefeet  regionidcity  \
# bathroomcnt                    0.115461           0.143177      0.012897
# bedroomcnt                     0.070756           0.219338      0.022241
# calculatedfinishedsquarefeet   0.093949           0.270736      0.015193
# latitude                      -0.639187           0.314863     -0.181988
# longitude                      1.000000          -0.085111      0.115153
# lotsizesquarefeet             -0.085111           1.000000     -0.051469
# regionidcity                   0.115153          -0.051469      1.000000
# regionidzip                    0.289255           0.190504      0.043823
# yearbuilt                      0.227210           0.029480      0.023437
# taxvaluedollarcnt              0.055008          -0.002825      0.071251
# taxamount                      0.034191           0.014265      0.064289
# logerror                       0.029892          -0.004917      0.022351
#
#                               regionidzip  yearbuilt  taxvaluedollarcnt  \
# bathroomcnt                      0.305933   0.605786           0.333486
# bedroomcnt                       0.248545   0.415431           0.166317
# calculatedfinishedsquarefeet     0.263213   0.532038           0.364303
# latitude                         0.124467  -0.003511          -0.165432
# longitude                        0.289255   0.227210           0.055008
# lotsizesquarefeet                0.190504   0.029480          -0.002825
# regionidcity                     0.043823   0.023437           0.071251
# regionidzip                      1.000000   0.570815           0.051112
# yearbuilt                        0.570815   1.000000           0.230771
# taxvaluedollarcnt                0.051112   0.230771           1.000000
# taxamount                        0.050116   0.241328           0.971708
# logerror                         0.030217   0.040874          -0.009620
#
#                               taxamount  logerror
# bathroomcnt                    0.340444  0.050648
# bedroomcnt                     0.176616  0.046402
# calculatedfinishedsquarefeet   0.369713  0.062921
# latitude                      -0.100355 -0.029925
# longitude                      0.034191  0.029892
# lotsizesquarefeet              0.014265 -0.004917
# regionidcity                   0.064289  0.022351
# regionidzip                    0.050116  0.030217
# yearbuilt                      0.241328  0.040874
# taxvaluedollarcnt              0.971708 -0.009620
# taxamount                      1.000000 -0.015615
# logerror                      -0.015615  1.000000

# %%
corr.logerror
# Out:
# bathroomcnt                     0.050648
# bedroomcnt                      0.046402
# calculatedfinishedsquarefeet    0.062921
# latitude                       -0.029925
# longitude                       0.029892
# lotsizesquarefeet              -0.004917
# regionidcity                    0.022351
# regionidzip                     0.030217
# yearbuilt                       0.040874
# taxvaluedollarcnt              -0.009620
# taxamount                      -0.015615
# logerror                        1.000000
# Name: logerror, dtype: float64

# %%
corr_p = pd.DataFrame(train.corr(method='pearson'))
corr_p
# Out:
#                               bathroomcnt  bedroomcnt  \
# bathroomcnt                      1.000000    0.574887
# bedroomcnt                       0.574887    1.000000
# calculatedfinishedsquarefeet     0.771876    0.604539
# latitude                         0.019810    0.029173
# longitude                        0.050280    0.012466
# lotsizesquarefeet                0.158058    0.221295
# regionidcity                    -0.061112   -0.051591
# regionidzip                      0.058442    0.045799
# yearbuilt                        0.568751    0.379954
# taxvaluedollarcnt                0.332524    0.168227
# taxamount                        0.338531    0.175911
# logerror                         0.020621    0.022630
#
#                               calculatedfinishedsquarefeet  latitude  \
# bathroomcnt                                       0.771876  0.019810
# bedroomcnt                                        0.604539  0.029173
# calculatedfinishedsquarefeet                      1.000000 -0.022319
# latitude                                         -0.022319  1.000000
# longitude                                         0.048381 -0.531576
# lotsizesquarefeet                                 0.275389  0.292855
# regionidcity                                     -0.054896 -0.001631
# regionidzip                                       0.050994  0.027175
# yearbuilt                                         0.513067  0.095435
# taxvaluedollarcnt                                 0.402272 -0.217839
# taxamount                                         0.404267 -0.130847
# logerror                                          0.022037 -0.025321
#
#                               longitude  lotsizesquarefeet  regionidcity  \
# bathroomcnt                    0.050280           0.158058     -0.061112
# bedroomcnt                     0.012466           0.221295     -0.051591
# calculatedfinishedsquarefeet   0.048381           0.275389     -0.054896
# latitude                      -0.531576           0.292855     -0.001631
# longitude                      1.000000          -0.109094     -0.014597
# lotsizesquarefeet             -0.109094           1.000000     -0.014722
# regionidcity                  -0.014597          -0.014722      1.000000
# regionidzip                    0.039751           0.017334     -0.023010
# yearbuilt                      0.099905          -0.003053     -0.106653
# taxvaluedollarcnt              0.036985           0.012969      0.007717
# taxamount                      0.023817           0.026859     -0.001390
# logerror                       0.019491          -0.006037      0.001379
#
#                               regionidzip  yearbuilt  taxvaluedollarcnt  \
# bathroomcnt                      0.058442   0.568751           0.332524
# bedroomcnt                       0.045799   0.379954           0.168227
# calculatedfinishedsquarefeet     0.050994   0.513067           0.402272
# latitude                         0.027175   0.095435          -0.217839
# longitude                        0.039751   0.099905           0.036985
# lotsizesquarefeet                0.017334  -0.003053           0.012969
# regionidcity                    -0.023010  -0.106653           0.007717
# regionidzip                      1.000000   0.111585           0.002036
# yearbuilt                        0.111585   1.000000           0.229418
# taxvaluedollarcnt                0.002036   0.229418           1.000000
# taxamount                       -0.000282   0.247459           0.967099
# logerror                         0.001255   0.009418          -0.023741
#
#                               taxamount  logerror
# bathroomcnt                    0.338531  0.020621
# bedroomcnt                     0.175911  0.022630
# calculatedfinishedsquarefeet   0.404267  0.022037
# latitude                      -0.130847 -0.025321
# longitude                      0.023817  0.019491
# lotsizesquarefeet              0.026859 -0.006037
# regionidcity                  -0.001390  0.001379
# regionidzip                   -0.000282  0.001255
# yearbuilt                      0.247459  0.009418
# taxvaluedollarcnt              0.967099 -0.023741
# taxamount                      1.000000 -0.027835
# logerror                      -0.027835  1.000000

# %%
corr_p.logerror
# Out:
# bathroomcnt                     0.020621
# bedroomcnt                      0.022630
# calculatedfinishedsquarefeet    0.022037
# latitude                       -0.025321
# longitude                       0.019491
# lotsizesquarefeet              -0.006037
# regionidcity                    0.001379
# regionidzip                     0.001255
# yearbuilt                       0.009418
# taxvaluedollarcnt              -0.023741
# taxamount                      -0.027835
# logerror                        1.000000
# Name: logerror, dtype: float64

# %%
def calculate_pvalues_spearman(df):
    df = df.select_dtypes(include=['number'])
    pairs = pd.MultiIndex.from_product([df.columns, df.columns])
    pvalues = [stats.spearmanr(df[a], df[b])[1] for a, b in pairs]
    pvalues = pd.Series(pvalues, index=pairs).unstack().round(4)
    return pvalues

# %%
pvalues_s = calculate_pvalues_spearman(train)

# %%
pvalues_s.logerror < alpha
# Out:
# bathroomcnt                      True
# bedroomcnt                       True
# calculatedfinishedsquarefeet     True
# latitude                         True
# logerror                         True
# longitude                        True
# lotsizesquarefeet               False
# regionidcity                     True
# regionidzip                      True
# taxamount                        True
# taxvaluedollarcnt               False
# yearbuilt                        True
# Name: logerror, dtype: bool

# %%
def calculate_pvalues_pearson(df):
    df = df.select_dtypes(include=['number'])
    pairs = pd.MultiIndex.from_product([df.columns, df.columns])
    pvalues = [stats.pearsonr(df[a], df[b])[1] for a, b in pairs]
    pvalues = pd.Series(pvalues, index=pairs).unstack().round(4)
    return pvalues

# %%
pvalues_p = calculate_pvalues_pearson(train)

# %%
pvalues_p.logerror < alpha
# Out:
# bathroomcnt                      True
# bedroomcnt                       True
# calculatedfinishedsquarefeet     True
# latitude                         True
# logerror                         True
# longitude                        True
# lotsizesquarefeet               False
# regionidcity                    False
# regionidzip                     False
# taxamount                        True
# taxvaluedollarcnt                True
# yearbuilt                       False
# Name: logerror, dtype: bool

# %% [markdown]
# Things to look into:
# - p > alpha on yearbuilt, regionidzip, regionidcity, lotsizesquarefeet on pearson corr
# - p > alpha on lotsizesquarefeet and taxvaluedollarcnt on spearman corr
# - extremely weak correlation between logerror and all values
# - highest correlation between log error and calculatedfinishedsquarefeet at 0.062921 with spearman
#
# Things to try next:
# - Look into data after clustering

# %%
plt.figure(figsize = (20,30))
sns.pairplot(data=train.sample(10000), x_vars=['logerror','bathroomcnt', 'bedroomcnt', 'calculatedfinishedsquarefeet', 'latitude', 'longitude', 'taxvaluedollarcnt', 'lotsizesquarefeet'],
                  y_vars=['logerror','bathroomcnt', 'bedroomcnt', 'calculatedfinishedsquarefeet', 'latitude', 'longitude', 'taxvaluedollarcnt', 'lotsizesquarefeet'], hue = "fips", corner=True)

# %% [markdown]
# **Latitude and longitude make clear county clusters**

# %% [markdown]
# ### Clustering

# %% [markdown]
# #### First glance at lat/long

# %%
X = train[['latitude','longitude']]

# %%
kmeans = KMeans(n_clusters=6)
kmeans.fit(X)

kmeans.predict(X)
# Out:
# array([4, 0, 5, ..., 3, 3, 3], dtype=int32)

# %%
train['clusters'] = kmeans.predict(X)

# %%
plt.figure(figsize=(18,5))
plt.subplot(131)
sns.scatterplot(data = train, x = 'longitude', y = 'latitude')
plt.title('Original Data')

plt.subplot(132)
sns.scatterplot(data = train, x = 'longitude', y = 'latitude', hue = 'fips')
plt.title('Actual Counties')

plt.subplot(133)
sns.scatterplot(data = train, x = 'longitude', y = 'latitude', hue = 'clusters', palette = ('tab10'))
plt.title('K-Means Clusters')
# Out:
# Text(0.5, 1.0, 'K-Means Clusters')

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(9, 6))
    pd.Series({k: KMeans(k).fit(X).inertia_ for k in range(2, 12)}).plot(marker='x')
    plt.xticks(range(2, 12))
    plt.xlabel('k')
    plt.ylabel('inertia')
    plt.title('Change in inertia as k increases')

# %%
fig, axs = plt.subplots(3, 2, figsize=(13, 13), sharex=True, sharey=True)

for ax, k in zip(axs.ravel(), range(2, 8)):
    clusters = KMeans(k).fit(X).predict(X)
    ax.scatter(train.longitude, train.latitude, c=clusters)
    ax.set(title='k = {}'.format(k), xlabel='longitutde', ylabel='latitude')

# %%
train_scaled, validate_scaled, test_scaled = wrangle_zillow.scale_data(train,validate,test)

# %% [markdown]
# #### Scaled data with features

# %%
X = train_scaled[[ 'yearbuilt','calculatedfinishedsquarefeet']]

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)

kmeans.predict(X)
# Out:
# array([3, 2, 4, ..., 4, 4, 1], dtype=int32)

# %%
train['clusters_scaled'] = kmeans.predict(X)

# %%
plt.figure(figsize=(18,5))
plt.subplot(131)
sns.scatterplot(data = train, x = 'longitude', y = 'latitude')
plt.title('Original Data')

plt.subplot(132)
sns.scatterplot(data = train, x = 'longitude', y = 'latitude', hue = 'fips')
plt.title('Actual Counties')

plt.subplot(133)
sns.scatterplot(data = train, x = 'longitude', y = 'latitude', hue = 'clusters_scaled', palette = ('tab10'))
plt.title('K-Means Clusters')
# Out:
# Text(0.5, 1.0, 'K-Means Clusters')

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(9, 6))
    pd.Series({k: KMeans(k).fit(X).inertia_ for k in range(2, 12)}).plot(marker='x')
    plt.xticks(range(2, 12))
    plt.xlabel('k')
    plt.ylabel('inertia')
    plt.title('Change in inertia as k increases')

# %% [markdown]
# **Notes: Looking at features doesn't really seem to help create meaningful clusters. With locational clustering we can divide the 3 counties to 6 regions and may be better able to predict log error.**

# %%
train.clusters_unscaled.value_counts()
# Out:
# 0    5025
# 1    4947
# 2    3834
# 5    3033
# 6    1894
# 4    1550
# 3    1445
# Name: clusters_unscaled, dtype: int64

# %% [markdown]
# #### set X,y train, validate, test

# %%
X_train = train_scaled.drop(columns =['logerror','fips','regionidcity', 'regionidzip', 'bedroomcnt', 'lotsizesquarefeet','taxamount','transactiondate', 'propertylandusedesc'])
y_train = train_scaled['logerror']

X_validate = validate_scaled.drop(columns =['logerror','fips','regionidcity', 'regionidzip', 'bedroomcnt', 'lotsizesquarefeet','taxamount','transactiondate', 'propertylandusedesc'])
y_validate = validate['logerror']

X_test = test_scaled.drop(columns =['logerror','fips','regionidcity', 'regionidzip', 'bedroomcnt', 'lotsizesquarefeet','taxamount','transactiondate', 'propertylandusedesc'])
y_test = test['logerror']

# %%
def map_clusters(train):
    # identified counties for fips codes 
    clusters = {0: '',
                1: '',
                2: '',
                3: '',
                4: '',
                5: '',
                6: ''}
    # map counties to fips codes
    df.clusters_unscaled = df.clusters_unscaled.map(clusters)
    return df

# %%
train_scaled.head(1)
# Out:
#        bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet         fips  \
# 46193     0.666667    0.333333                      0.961698  Los_Angeles
#
#        latitude  longitude  lotsizesquarefeet  regionidcity  regionidzip  \
# 46193  0.975952   0.657953           0.493775          5534        97319
#
#        yearbuilt  taxvaluedollarcnt  taxamount  logerror transactiondate  \
# 46193   0.929293           0.217873       5002  0.047455      2017-08-18
#
#              propertylandusedesc  clusters  clusters_unscaled  clusters_scaled
# 46193  Single Family Residential         4                  4                3
